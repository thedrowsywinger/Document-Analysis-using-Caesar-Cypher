# %%
import nltk
# nltk.download('words')

# %%
from nltk.corpus import words

# %%
"would" in words.words()
# Out:
# True

# %%
file = "./data.txt"

# %%
input_file = open(file, "rt")
data = input_file.read()

# %%
import re
data = re.sub('[!@#$"%&(?)*+-./0123456789:;<>=@[\\]^_{}|`~\n]', '', data)

# %%
words_list = data.split()
print('Number of words in text file :', len(words_list))
# Out:
# Number of words in text file : 9454

# %%
number_of_characters = len(data)
print('Number of characters in text file :', number_of_characters)
# Out:
# Number of characters in text file : 62856

# %%
frequency_dictionary = {} 
  
for keys in data: 
    frequency_dictionary[keys] = frequency_dictionary.get(keys, 0) + 1

# %%
frequency_dictionary
# Out:
# {'C': 2135,
#  'N': 4143,
#  'E': 3454,
#  'G': 4451,
#  'V': 3569,
#  'P': 1916,
#  'H': 1621,
#  'Y': 2092,
#  ' ': 9589,
#  'R': 6366,
#  'B': 4400,
#  'Q': 1762,
#  'S': 1077,
#  'X': 422,
#  'A': 3859,
#  'F': 3548,
#  'O': 912,
#  'Z': 1522,
#  "'": 259,
#  'I': 563,
#  'J': 652,
#  'U': 2061,
#  'K': 288,
#  'L': 909,
#  'W': 73,
#  'T': 1096,
#  'D': 58,
#  'M': 56,
#  '\\': 3}

# %%
frequency_dictionary_new = {}
for key, value in frequency_dictionary.items():
    a = value
    b = 100/number_of_characters
    percentage = a * b
    percentage = round(percentage,2)
    frequency_dictionary_new[key] = percentage

# %%
frequency_dictionary_new
# Out:
# {'C': 3.4,
#  'N': 6.59,
#  'E': 5.5,
#  'G': 7.08,
#  'V': 5.68,
#  'P': 3.05,
#  'H': 2.58,
#  'Y': 3.33,
#  ' ': 15.26,
#  'R': 10.13,
#  'B': 7.0,
#  'Q': 2.8,
#  'S': 1.71,
#  'X': 0.67,
#  'A': 6.14,
#  'F': 5.64,
#  'O': 1.45,
#  'Z': 2.42,
#  "'": 0.41,
#  'I': 0.9,
#  'J': 1.04,
#  'U': 3.28,
#  'K': 0.46,
#  'L': 1.45,
#  'W': 0.12,
#  'T': 1.74,
#  'D': 0.09,
#  'M': 0.09,
#  '\\': 0.0}

# %%
word_validity_dictionary = {}

for w in words_list:
    word_validity_dictionary[w] = w in words.words()

# %%
word_validity_dictionary
# Out:
# {'CNEGVPHYNE': False,
#  'CREVBQ': False,
#  'BS': False,
#  'SYNXVARFF': False,
#  'BA': False,
#  "VOZ'F": False,
#  'IARG': False,
#  'PBECBENGR': False,
#  'ARGJBEX': False,
#  'PN.': False,
#  '1988;': False,
#  'OHG': False,
#  'GURER': False,
#  'NER': False,
#  'VAQRCRAQRAG': False,
#  'ERCBEGF': False,
#  'GUR': False,
#  'GREZ': False,
#  'SEBZ': False,
#  'RYFRJURER.': False,
#  '_________________________________________________________________': False,
#  'ABQR:AC-,': False,
#  'ARKG:[9529]AEBSS,': False,
#  'CERIVBHF:[9530]ABGJBEX,': False,
#  'HC:[9531]=': False,
#  'A': True,
#  '=': False,
#  'AC-': False,
#  '/A-C/': False,
#  'CERS.': False,
#  'RKGERZRYL.': False,
#  'HFRQ': False,
#  'GB': False,
#  'ZBQVSL': False,
#  'NQWRPGVIRF': False,
#  'QRFPEVOVAT': False,
#  'N': True,
#  'YRIRY': False,
#  'BE': False,
#  'DHNYVGL': False,
#  'QVSSVPHYGL;': False,
#  'PBAABGNGVBA': False,
#  'VF': False,
#  'BSGRA': False,
#  '`ZBER': False,
#  'FB': False,
#  'GUNA': False,
#  'VG': False,
#  'FUBHYQ': False,
#  "OR'": False,
#  'GUVF': False,
#  'TRARENYVMRQ': False,
#  'PBZCHGRE-FPVRAPR': False,
#  'GREZF': False,
#  "`AC-UNEQ'": False,
#  'NAQ': False,
#  "`AC-PBZCYRGR';": False,
#  'AC-PBZCYRGR': False,
#  'CEBOYRZF': False,
#  'NYY': False,
#  'FRRZ': False,
#  'OR': False,
#  'IREL': False,
#  'UNEQ,': False,
#  'SNE': False,
#  'AB': False,
#  'BAR': False,
#  'UNF': False,
#  'SBHAQ': False,
#  'CEBBS': False,
#  'GUNG': False,
#  'GURL': False,
#  'NER.': False,
#  'AC': False,
#  'FRG': False,
#  'ABAQRGREZVAVFGVP-CBYLABZVNY': False,
#  'NYTBEVGUZF,': False,
#  'GUBFR': False,
#  'PNA': False,
#  'PBZCYRGRQ': False,
#  'OL': False,
#  'ABAQRGREZVAVFGVP': False,
#  'GHEVAT': False,
#  'ZNPUVAR': False,
#  'VA': False,
#  'NA': False,
#  'NZBHAG': False,
#  'GVZR': False,
#  'CBYLABZVNY': False,
#  'SHAPGVBA': False,
#  'FVMR': False,
#  'VACHG;': False,
#  'FBYHGVBA': False,
#  'SBE': False,
#  'CEBOYRZ': False,
#  'JBHYQ': False,
#  'FBYIR': False,
#  'BGUREF.': False,
#  '"PBQVAT': False,
#  'OVGOYG': False,
#  'VZCYRZRAGNGVBA': False,
#  'CRESBEZ': False,
#  'PBEERPGYL': False,
#  'RIREL': False,
#  'PNFR': False,
#  'AC-NAABLVAT."': False,
#  'ABGR,': False,
#  'UBJRIRE,': False,
#  'FGEVPGYL': False,
#  'FCRNXVAT': False,
#  'HFNTR': False,
#  'ZVFYRNQVAT;': False,
#  'CYRAGL': False,
#  'RNFL': False,
#  'PYNFF': False,
#  'AC.': False,
#  'UNEQ': False,
#  'ABG': False,
#  'ORPNHFR': False,
#  'AC,': False,
#  'UNEQRFG': False,
#  'ABQR:AEBSS,': False,
#  'ARKG:[9532]AFN': False,
#  'YVAR': False,
#  'RNGRE,': False,
#  'CERIVBHF:[9533]AC-,': False,
#  'HC:[9534]=': False,
#  'AEBSS': False,
#  "/A'EBS/": False,
#  'A.': False,
#  '[HAVK,': False,
#  '"ARJ': False,
#  'EBSS"': False,
#  '(FRR': False,
#  '[9535]GEBSS)]': False,
#  'PBZCNAVBA': False,
#  'CEBTENZ': False,
#  'HAVK': False,
#  'GLCRFRGGRE': False,
#  '[9536]GEBSS,': False,
#  'NPPRCGVAT': False,
#  'VQRAGVPNY': False,
#  'VACHG': False,
#  'CERCNEVAT': False,
#  'BHGCHG': False,
#  'GREZVANYF': False,
#  'CEVAGREF.': False,
#  'ABQR:AFN': False,
#  'ARKG:[9537]AFC,': False,
#  'CERIVBHF:[9538]AEBSS,': False,
#  'HC:[9539]=': False,
#  'AFN': False,
#  'RNGRE': False,
#  'ANGVBANY': False,
#  'FRPHEVGL': False,
#  'NTRAPL': False,
#  'GENJYVAT': False,
#  'FBZRGVZRF': False,
#  'NFFHZRQ': False,
#  'ERNQVAT': False,
#  'ARG': False,
#  'H.F.': False,
#  "TBIREAZRAG'F": False,
#  'FCBBXF.': False,
#  'ZBFG': False,
#  'UNPXREF': False,
#  'GUVAX': False,
#  'JNF': False,
#  'ZLGUVPNY': False,
#  'ORYVRIRQ': False,
#  'NPGVAT': False,
#  'NF': False,
#  'GUBHTU': False,
#  'RKVFGRQ': False,
#  'WHFG': False,
#  'PNFR.': False,
#  'FVAPR': False,
#  'ZVQ-1990F': False,
#  'TENQHNYYL': False,
#  'ORPBZR': False,
#  'XABJA': False,
#  'NPGHNYYL': False,
#  'QBRF': False,
#  'GUVF,': False,
#  'DHVGR': False,
#  'VYYRTNYL,': False,
#  'GUEBHTU': False,
#  'VGF': False,
#  'RPURYBA': False,
#  'CEBTENZ.': False,
#  'FGNAQNEQ': False,
#  'PBHAGREZRNFHER': False,
#  'CHG': False,
#  'YBNQRQ': False,
#  'CUENFRF': False,
#  'YVXR': False,
#  "`XTO',": False,
#  "`HMV',": False,
#  '`AHPYRNE': False,
#  "ZNGREVNYF',": False,
#  "`CNYRFGVAR',": False,
#  "`PBPNVAR',": False,
#  "`NFFNFFVANGVBA'": False,
#  'GURVE': False,
#  '[9540]FVT': False,
#  'OYBPXF': False,
#  '(CEBONOYL': False,
#  'SHGVYR)': False,
#  'NGGRZCG': False,
#  'PBASHFR': False,
#  'BIREYBNQ': False,
#  'PERNGHER.': False,
#  '[9541]TAH': False,
#  'IREFVBA': False,
#  '[9542]RZNPF': False,
#  'PBZZNAQ': False,
#  'ENAQBZYL': False,
#  'VAFREGF': False,
#  'OHAPU': False,
#  'VAFVQVBHF': False,
#  'NANEPUB-IREOVNTR': False,
#  'VAGB': False,
#  'LBHE': False,
#  'RQVGRQ': False,
#  'GRKG.': False,
#  'ONPX': False,
#  '1970F': False,
#  'ZNVAFGERNZ': False,
#  'INEVNAG': False,
#  'ZLGU': False,
#  'VAIBYIVAT': False,
#  '`GEHAX': False,
#  "ZBAVGBE',": False,
#  'JUVPU': False,
#  'FHCCBFRQYL': False,
#  'FCRRPU': False,
#  'ERPBTAVGVBA': False,
#  'RKGENPG': False,
#  'JBEQF': False,
#  'GRYRCUBAR': False,
#  'GEHAXF.': False,
#  'ZHPU': False,
#  'UNEQRE': False,
#  'ABGVPVAT': False,
#  'XRLJBEQF': False,
#  'RZNVY,': False,
#  'CRBCYR': False,
#  'JUB': False,
#  'BEVTVANYYL': False,
#  'CEBCNTNGRQ': False,
#  'UNQ': False,
#  'VQRN': False,
#  'GURA-PHEERAG': False,
#  'GRPUABYBTL': False,
#  'FGBENTR,': False,
#  'FVTANY-CEBPRFFVAT,': False,
#  'ARRQF': False,
#  'FHPU': False,
#  'CEBWRPG.': False,
#  'ONFVF': False,
#  'ZNFF-FGBENTR': False,
#  'PBFGF': False,
#  'NYBAR': False,
#  'UNIR': False,
#  'ORRA': False,
#  'PURNCRE': False,
#  'UVER': False,
#  '50': False,
#  'UVTU-FPUBBY': False,
#  'FGHQRAGF': False,
#  'YRG': False,
#  'GURZ': False,
#  'YVFGRA': False,
#  'VA.': False,
#  'GJRAGL': False,
#  'LRNEF': False,
#  'FRIRENY': False,
#  'BEQREF': False,
#  'GRPUABYBTVPNY': False,
#  'ZNTAVGHQR': False,
#  'YNGRE,': False,
#  'PYRNE': False,
#  'VAQVPNGVBAF': False,
#  'QRCYBLRQ': False,
#  'SVYGREVAT': False,
#  '(NTNVA,': False,
#  'NTNVAFG': False,
#  'YNJ).': False,
#  'ABQR:AFC,': False,
#  'ARKG:[9543]AHQR,': False,
#  'CERIVBHF:[9544]AFN': False,
#  'HC:[9545]=': False,
#  'AFC': False,
#  '/A-F-C/': False,
#  'PBZZBA': False,
#  'NOOERIVNGVBA': False,
#  '`ARGJBEX': False,
#  'FREIVPR': False,
#  "CEBIVQRE',": False,
#  'OVT': False,
#  'ERTVBANY': False,
#  'PBZCNAVRF': False,
#  'ZNVAGNVAF': False,
#  'CBEGVBA': False,
#  'VAGREARG': False,
#  'ONPXOBAR': False,
#  'ERFRYYF': False,
#  'PBAARPGVIVGL': False,
#  '[9546]VFCF.': False,
#  '1996,': False,
#  'ZNWBE': False,
#  'AFCF': False,
#  'VAPYHQR': False,
#  'NAF,': False,
#  'ZPV,': False,
#  'HHARG,': False,
#  'FCEVAG.': False,
#  'JUBYRFNYRE.': False,
#  'ABQR:AHQR,': False,
#  'ARKG:[9547]AHTEL,': False,
#  'CERIVBHF:[9548]AFC,': False,
#  'HC:[9549]=': False,
#  'AHQR': False,
#  'NQW.': False,
#  'FNVQ': False,
#  'ZNPUVARF': False,
#  'QRYVIRERQ': False,
#  'JVGUBHG': False,
#  'BCRENGVAT': False,
#  'FLFGRZ': False,
#  '(PBZCNER': False,
#  '[9550]ONER': False,
#  'ZRGNY).': False,
#  '"JR': False,
#  'BEQRERQ': False,
#  'FLFGRZF,': False,
#  'NEEVIRQ': False,
#  'AHQR,': False,
#  'JR': False,
#  'FCRAQ': False,
#  'RKGEN': False,
#  'JRRXRAQ': False,
#  'JVGU': False,
#  'VAFGNYYNGVBA': False,
#  'QVFXF."': False,
#  'ERPRAG': False,
#  'VAABINGVBA': False,
#  'ERSYRPGVAT': False,
#  'SNPG': False,
#  'VOZ-CP': False,
#  'PYBARF': False,
#  'ABJ': False,
#  'CER-VAFGNYYRQ': False,
#  'NG': False,
#  'SNPGBEL.': False,
#  'BGURE': False,
#  'XVAQF': False,
#  'UNEQJNER': False,
#  'FGVYY': False,
#  'ABEZNYYL': False,
#  'BF,': False,
#  'CP': False,
#  'FHCCBEG': False,
#  'TEBHCF.': False,
#  'ABQR:AHTEL,': False,
#  'ARKG:[9551]AHXR,': False,
#  'CERIVBHF:[9552]AHQR,': False,
#  'HC:[9553]=': False,
#  'AHTEL': False,
#  "/A[L]BB'TERR/": False,
#  '[HFRARG,': False,
#  "'ARJOVR'": False,
#  '+': False,
#  "'-TEL']": False,
#  '`.': False,
#  '[9554]ARJOVR': False,
#  'CBFGF': False,
#  '[9555]SND': False,
#  'ERP.CHMMYRF': False,
#  'ARJFTEBHC,': False,
#  'RFCRPVNYYL': False,
#  'VS': False,
#  'ABGBEVBHF': False,
#  'HANAFJRENOYR': False,
#  '"JUNG,': False,
#  'ORFVQRF': False,
#  "`NATEL'": False,
#  "`UHATEL',": False,
#  'GUVEQ': False,
#  'RATYVFU': False,
#  'JBEQ': False,
#  'RAQF': False,
#  '-TEL?".': False,
#  'PNABAVPNY': False,
#  'NAFJRE': False,
#  'PBHEFR': False,
#  "`AHTEL'": False,
#  'VGFRYS.': False,
#  'CYHENY': False,
#  "`AHFTEL'": False,
#  "/A[L]BBF'TERR/.": False,
#  '2.': False,
#  'UNIVAT': False,
#  'DHNYVGVRF': False,
#  'AHTEL.': False,
#  'ABQR:AHXR,': False,
#  'ARKG:[9556]AHZORE-PEHAPUVAT,': False,
#  'CERIVBHF:[9557]AHTEL,': False,
#  'HC:[9558]=': False,
#  'AHXR': False,
#  '/A[L]BBX/': False,
#  'IG.': False,
#  '[PBZZBA]': False,
#  '1.': False,
#  'VAGRAGVBANYYL': False,
#  'QRYRGR': False,
#  'RAGVER': False,
#  'PBAGRAGF': False,
#  'TVIRA': False,
#  'QVERPGBEL': False,
#  'FGBENTR': False,
#  'IBYHZR.': False,
#  '"BA': False,
#  'HAVK,': False,
#  'EZ': False,
#  '-E': False,
#  '/HFE': False,
#  'JVYY': False,
#  'RIRELGUVAT': False,
#  'HFE': False,
#  'SVYRFLFGRZ."': False,
#  'ARIRE': False,
#  'NPPVQRAGNY': False,
#  'QRYRGVBA;': False,
#  'PBAGENFG': False,
#  '[9559]OYBJ': False,
#  'NJNL.': False,
#  'FLA.': False,
#  '[9560]QVXR,': False,
#  'NCCYVRQ': False,
#  'FZNYYRE': False,
#  'GUVATF': False,
#  'SVYRF,': False,
#  'SRNGHERF,': False,
#  'PBQR': False,
#  'FRPGVBAF.': False,
#  'RKCERFF': False,
#  'SVANY': False,
#  'IREQVPG.': False,
#  '"JUNG': False,
#  'QB': False,
#  'LBH': False,
#  'JNAG': False,
#  'ZR': False,
#  '80-ZRT': False,
#  '[9561]JNYYCNCRE': False,
#  'SVYR?"': False,
#  '"AHXR': False,
#  'VG."': False,
#  '3.': False,
#  'CEBPRFFRF': False,
#  'JRYY': False,
#  'SVYRF;': False,
#  'SERDHRAG': False,
#  'IREONY': False,
#  'NYVNF': False,
#  'XVYY': False,
#  '-9': False,
#  'HAVK.': False,
#  '4.': False,
#  'VOZ': False,
#  'CPF,': False,
#  'OHT': False,
#  'ERFHYGF': False,
#  '[9562]SNAQNATB': False,
#  'PBER': False,
#  'GENFU': False,
#  'FLFGRZ,': False,
#  'VAPYHQVAT': False,
#  'SNG': False,
#  '(GUR': False,
#  'VA-PBER': False,
#  'PBCL': False,
#  'QVFX': False,
#  'OYBPX': False,
#  'PUNVAVAT': False,
#  'VASBEZNGVBA).': False,
#  'HGGREYL': False,
#  'FPENZOYR': False,
#  'NGGNPURQ': False,
#  'QVFXF,': False,
#  'GURA': False,
#  "`AHXRQ'.": False,
#  'NYFB': False,
#  'NANYBTBHF': False,
#  'YBFFNTRF': False,
#  'ZNPVAGBFURF': False,
#  'ZVPEBF': False,
#  'ZRZBEL': False,
#  'CEBGRPGVBA.': False,
#  'ABQR:AHZORE-PEHAPUVAT,': False,
#  'ARKG:[9563]AHZOREF,': False,
#  'CERIVBHF:[9564]AHXR,': False,
#  'HC:[9565]=': False,
#  'AHZORE-PEHAPUVAT': False,
#  'PBZCHGNGVBAF': False,
#  'AHZREVPNY': False,
#  'ANGHER,': False,
#  'RFC.': False,
#  'ZNXR': False,
#  'RKGRAFVIR': False,
#  'HFR': False,
#  'SYBNGVAT-CBVAG': False,
#  'AHZOREF.': False,
#  'BAYL': False,
#  'GUVAT': False,
#  '[9566]SBEGENFU': False,
#  'TBBQ': False,
#  'SBE.': False,
#  'JVQRFCERNQ': False,
#  'VASBEZNY': False,
#  'BHGFVQR': False,
#  'UNPXREQBZ': False,
#  'RIRA': False,
#  'FYNAT,': False,
#  'NQQVGVBANY': False,
#  'UNPXVFU': False,
#  'PBAABGNGVBAF:': False,
#  'ANZRYL,': False,
#  'ZVAQYRFF': False,
#  'VAIBYIR': False,
#  'ZNFFVIR': False,
#  '[9567]OEHGR': False,
#  'SBEPR.': False,
#  'NYJNLF': False,
#  '[9568]RIVY,': False,
#  'VAIBYIRF': False,
#  'ENL': False,
#  'GENPVAT': False,
#  'SENPGNYF': False,
#  'FBZR': False,
#  'ZNXRF': False,
#  '[9569]CERGGL': False,
#  'CVPGHERF,': False,
#  'CVPGHERF': False,
#  '[9570]JNYYCNCRE.': False,
#  'FRR': False,
#  '[9571]PEHAPU.': False,
#  'ABQR:AHZOREF,': False,
#  'ARKG:[9572]AHKV': False,
#  'CEBOYRZ,': False,
#  'CERIVBHF:[9573]AHZORE-PEHAPUVAT,': False,
#  'HC:[9574]=': False,
#  'AHZOREF': False,
#  '[FPVRAGVSVP': False,
#  'PBZCHGNGVBA]': False,
#  'PBZCHGNGVBA': False,
#  'ZNL': False,
#  'FVTAVSVPNAG': False,
#  'YRNFG': False,
#  'VAQVPNGR': False,
#  'EHAAVAT.': False,
#  'CYNPNGR': False,
#  'ZNANTRZRAG,': False,
#  'TENAG': False,
#  'FCBAFBEF,': False,
#  'RGP.': False,
#  '`ZNXVAT': False,
#  "AHZOREF'": False,
#  'ZRNAF': False,
#  'EHAAVAT': False,
#  '--': False,
#  'NAL': False,
#  'BHGCHG,': False,
#  'ARPRFFNEVYL': False,
#  'ZRNAVATSHY': False,
#  'ARRQRQ': False,
#  'QRZBAFGENGVBA': False,
#  'CEBTERFF.': False,
#  '[9575]CERGGL': False,
#  '[9576]ZNGU-BHG,': False,
#  '[9577]FBPVNY': False,
#  'FPVRAPR': False,
#  'AHZORE.': False,
#  'ABQR:AHKV': False,
#  'ARKG:[9578]ALOOYR,': False,
#  'CERIVBHF:[9579]AHZOREF,': False,
#  'HC:[9580]=': False,
#  'AHKV': False,
#  "/AHX'FRR": False,
#  "CEB'OY*Z/": False,
#  'ERSREF': False,
#  'GENAFSREEVAT': False,
#  'QNGN': False,
#  'ORGJRRA': False,
#  'QVSSREVAT': False,
#  'OLGR-BEQRE.': False,
#  'FGEVAT': False,
#  "`HAVK'": False,
#  'ZVTUG': False,
#  'YBBX': False,
#  "`AHKV'": False,
#  'QVSSRERAG': False,
#  '`OLGR': False,
#  "FRK'": False,
#  '(R.T.,': False,
#  'JURA': False,
#  '[9581]YVGGYR-RAQVNA': False,
#  '[9582]OVT-RAQVNA,': False,
#  'IVPR-IREFN).': False,
#  '[9583]ZVQQYR-RAQVNA,': False,
#  '[9584]FJNO,': False,
#  '[9585]OLGRFRKHNY.': False,
#  'ABQR:ALOOYR,': False,
#  'ARKG:[9586]ALRGJBEX,': False,
#  'CERIVBHF:[9587]AHKV': False,
#  'HC:[9588]=': False,
#  'ALOOYR': False,
#  "/AVO'Y/": False,
#  '(NYG.': False,
#  "`AVOOYR')": False,
#  '[SEBZ': False,
#  'I.': False,
#  "`AVOOYR'": False,
#  'NANYBTL': False,
#  "`OVGR'": False,
#  '=>': False,
#  "`OLGR']": False,
#  'SBHE': False,
#  'OVGF;': False,
#  '[9589]URK': False,
#  'QVTVG;': False,
#  'UNYS-OLGR.': False,
#  "`OLGR'": False,
#  'GRPUFCRNX,': False,
#  'HFRSHY': False,
#  'ERYNGVIR': False,
#  'WNETBA.': False,
#  'PBZCNER': False,
#  '[9590]OLGR;': False,
#  '[9591]OVG.': False,
#  'ZBER': False,
#  'ZHAQNAR': False,
#  'FCRYYVAT': False,
#  '"AVOOYR"': False,
#  'PBZZBAYL': False,
#  'HFRQ.': False,
#  'NCCNERAGYL': False,
#  "`ALOOYR'": False,
#  'HAPBZZBA': False,
#  'PBZZBAJRNYGU': False,
#  'UNPXVFU,': False,
#  'OEVGVFU': False,
#  'BEGUBTENCUL': False,
#  'FHTTRFG': False,
#  'CEBAHAPVNGVBA': False,
#  "/AV:'OY/.": False,
#  'SBYYBJVAT': False,
#  "`OVG',": False,
#  'SRJ': False,
#  'NANYBTVPNY': False,
#  'NGGRZCGF': False,
#  'PBAFGEHPG': False,
#  'HANZOVTHBHF': False,
#  'OVG': False,
#  'FVMRF.': False,
#  'GURFR': False,
#  'WNETBA,': False,
#  'WNETBA': False,
#  '(ZBFG': False,
#  'ERPBTAVMR': False,
#  'PBAGRKG': False,
#  'FCBAGNARBHFYL).': False,
#  'PBYYRPG': False,
#  'URER': False,
#  'ERSRERAPR': False,
#  'GBTRGURE': False,
#  'NZOVTHBHF': False,
#  'GRPUFCRNX': False,
#  "`JBEQ',": False,
#  "`UNYS-JBEQ'": False,
#  '`QBHOYR': False,
#  "JBEQ';": False,
#  '(VAQVPNGRQ)': False,
#  'FHOFGNAGVNY': False,
#  'VASBEZNGVBA': False,
#  'FRCNENGR': False,
#  'RAGEVRF.': False,
#  '2': False,
#  'OVGF:': False,
#  '[9592]PEHZO,': False,
#  '[9593]DHNQ,': False,
#  '[9594]DHNEGRE,': False,
#  'GNLFGR,': False,
#  'GLQOVG': False,
#  '4': False,
#  '5': False,
#  '[9595]AVPXYR': False,
#  '10': False,
#  '[9596]QRPXYR': False,
#  '16': False,
#  'CYNLGR,': False,
#  '[9597]PUNJZC': False,
#  '(BA': False,
#  '32-OVG': False,
#  'ZNPUVAR),': False,
#  '16-OVG': False,
#  'UNYS-JBEQ': False,
#  'ZNPUVAR).': False,
#  '18': False,
#  '[9598]PUNJZC': False,
#  '36-OVG': False,
#  'ZNPUVAR)': False,
#  '32': False,
#  'QLAARE,': False,
#  '[9599]TNJOYR': False,
#  'YBATJBEQ': False,
#  '36:': False,
#  '48': False,
#  '[9600]TNJOYR': False,
#  '(HAQRE': False,
#  'PVEPHZFGNAPRF': False,
#  'ERZNVA': False,
#  'BOFPHER)': False,
#  '64': False,
#  'OVGF': False,
#  'QBHOYR': False,
#  'SHAQNZRAGNY': False,
#  'ZBGVINGVBA': False,
#  '(NFVQR': False,
#  'ABEZNY': False,
#  'UNPXREYL': False,
#  'RAWBLZRAG': False,
#  'CHAAVAT': False,
#  'JBEQCYNL)': False,
#  'RKGERZR': False,
#  'NZOVTHVGL': False,
#  "`JBEQ'": False,
#  'QREVINGVIRF.': False,
#  'ABQR:ALRGJBEX,': False,
#  'ARKG:[9601]BO-,': False,
#  'CERIVBHF:[9602]ALOOYR,': False,
#  'HC:[9603]=': False,
#  'ALRGJBEX': False,
#  "/ALRG'JREX/": False,
#  'EHFFVNA': False,
#  "`ALRG'": False,
#  'AB]': False,
#  'ARGJBEX,': False,
#  '[9604]SYNXL': False,
#  '[9605]QBJA.': False,
#  '[9606]ABGJBEX.': False,
#  'ABQR:=': False,
#  'B': True,
#  '=,': False,
#  'ARKG:[9607]=': False,
#  'C': True,
#  'CERIVBHF:[9608]=': False,
#  'HC:[9609]GUR': False,
#  'YRKVPBA': False,
#  '*': False,
#  '[9610]BO-:': False,
#  '[9611]BOSHFPNGRQ': False,
#  'P': True,
#  'PBAGRFG:': False,
#  '[9612]BOV-JNA': False,
#  'REEBE:': False,
#  '[9613]BOWRPGVBANOYR-P:': False,
#  '[9614]BOFPHER:': False,
#  '[9615]BPGNY': False,
#  'SBEGL:': False,
#  '[9616]BSS': False,
#  'GEBYYRL:': False,
#  '[9617]BSS-OL-BAR': False,
#  '[9618]BSSYVAR:': False,
#  '[9619]BTT:': False,
#  '[9620]-BVQ:': False,
#  '[9621]BYQ': False,
#  'SNEG:': False,
#  '[9622]BYQ': False,
#  'GRFGNZRAG:': False,
#  '[9623]BA': False,
#  'TEVCCVAT': False,
#  'UNAQ:': False,
#  '[9624]BAR-ONANAN': False,
#  'CEBOYRZ:': False,
#  '[9625]BAR-YVAR': False,
#  'SVK:': False,
#  '[9626]BAR-YVARE': False,
#  'JNEF:': False,
#  '[9627]BBOYVPX:': False,
#  '[9628]BC:': False,
#  '[9629]BCRA:': False,
#  '[9630]BCRA': False,
#  'FBHEPR:': False,
#  '[9631]BCRA': False,
#  'FJVGPU:': False,
#  '[9632]BCRENGVAT': False,
#  'FLFGRZ:': False,
#  '[9633]BCGVPNY': False,
#  'QVSS:': False,
#  '[9634]BCGVPNY': False,
#  'TERC:': False,
#  '[9635]BCGVZVFZ:': False,
#  '[9636]BENPYR': False,
#  'GUR:': False,
#  '[9637]BENATR': False,
#  'OBBX:': False,
#  '[9638]BEVRAGNY': False,
#  'SBBQ:': False,
#  '[9639]BECUNA:': False,
#  '[9640]BECUNARQ': False,
#  'V-ABQR:': False,
#  '[9641]BEGUBTBANY:': False,
#  '[9642]BF:': False,
#  '[9643]BF/2:': False,
#  '[9644]BFF:': False,
#  '[9645]BFH:': False,
#  '[9646]BGBU:': False,
#  '[9647]BHG-BS-ONAQ:': False,
#  '[9648]BIREPYBPX:': False,
#  '[9649]BIRESYBJ': False,
#  'OVG:': False,
#  '[9650]BIRESYBJ': False,
#  'CQY:': False,
#  '[9651]BIREEHA:': False,
#  '[9652]BIREEHA': False,
#  'FPERJ:': False,
#  'ABQR:BO-,': False,
#  'ARKG:[9653]BOSHFPNGRQ': False,
#  'PBAGRFG,': False,
#  'CERIVBHF:[9654]ALRGJBEX,': False,
#  'HC:[9655]=': False,
#  'BO-': False,
#  '/BO/': False,
#  'BOYVTNGBEL.': False,
#  'CVRPR': False,
#  '[9656]ARGVDHRGGR': False,
#  'NPXABJYRQTVAT': False,
#  'NHGUBE': False,
#  'FGENLVAT': False,
#  "ARJFTEBHC'F": False,
#  'PUNEGRE': False,
#  'GBCVP.': False,
#  'RKNZCYR,': False,
#  'CBFGVAT': False,
#  'NYG.FRK': False,
#  'ERFCBAFR': False,
#  'CNEG': False,
#  'FBZRBAR': False,
#  "RYFR'F": False,
#  'ABGUVAT': False,
#  'CNEGVPHYNEYL': False,
#  'FRK,': False,
#  'NCCRAQ': False,
#  "`BOFRK'": False,
#  '(BE': False,
#  "`BOFRK')": False,
#  'GBFF': False,
#  'BSS': False,
#  'DHRFGVBA': False,
#  'IVTARGGR': False,
#  'NOBHG': False,
#  'HAHFHNY': False,
#  'REBGVP': False,
#  'NPG.': False,
#  'PBAFVQRERQ': False,
#  'FVTA': False,
#  'TERNG': False,
#  '[9657]JVAAVGHQR': False,
#  "BAR'F": False,
#  'BOF': False,
#  'VAGRERFGVAT': False,
#  "CRBCYR'F": False,
#  'JUBYR': False,
#  'CBFGVATF.': False,
#  'ABQR:BOSHFPNGRQ': False,
#  'ARKG:[9658]BOV-JNA': False,
#  'REEBE,': False,
#  'CERIVBHF:[9659]BO-,': False,
#  'HC:[9660]=': False,
#  'BOSHFPNGRQ': False,
#  'PBAGRFG': False,
#  '(VA': False,
#  'SHYY,': False,
#  '`VAGREANGVBANY': False,
#  "PBAGRFG',": False,
#  'VBPPP)': False,
#  'NAAHNY': False,
#  'EHA': False,
#  '1984': False,
#  'BIRE': False,
#  'HFRARG': False,
#  'YNAQBA': False,
#  'PHEG': False,
#  'ABYY': False,
#  'SEVRAQF.': False,
#  'BIRENYY': False,
#  'JVAARE': False,
#  'JUBRIRE': False,
#  'CEBQHPRF': False,
#  'HAERNQNOYR,': False,
#  'PERNGVIR,': False,
#  'OVMNEER': False,
#  '(OHG': False,
#  'JBEXVAT)': False,
#  'CEBTENZ;': False,
#  'INEVBHF': False,
#  'CEVMRF': False,
#  'NJNEQRQ': False,
#  "WHQTRF'": False,
#  'JUVZ.': False,
#  "P'F": False,
#  'GREFR': False,
#  'FLAGNK': False,
#  'ZNPEB-CERCEBPRFFBE': False,
#  'SNPVYVGVRF': False,
#  'TVIR': False,
#  'PBAGRFGNAGF': False,
#  'YBG': False,
#  'ZNARHIREVAT': False,
#  'EBBZ.': False,
#  'JVAAVAT': False,
#  'CEBTENZF': False,
#  'ZNANTR': False,
#  'FVZHYGNARBHFYL': False,
#  '(N)': False,
#  'SHAAL,': False,
#  '(O)': False,
#  'OERNGUGNXVAT': False,
#  'JBEXF': False,
#  'NEG,': False,
#  '(P)': False,
#  'UBEEVOYR': False,
#  'RKNZCYRF': False,
#  'UBJ': False,
#  'P.': False,
#  'ERYNGVIRYL': False,
#  'FUBEG': False,
#  'FJRRG': False,
#  'RAGEL': False,
#  'URYC': False,
#  'PBAIRL': False,
#  'SYNIBE': False,
#  'P:': False,
#  '/*': False,
#  'URYYB': False,
#  'JBEYQ': False,
#  'WNPX': False,
#  'NCCYVA': False,
#  'EBOREG': False,
#  'URPXRAQBEA,': False,
#  '1985': False,
#  '(ABGR:': False,
#  'QRCRAQF': False,
#  'ORVAT': False,
#  'NOYR': False,
#  'RYRZRAGF': False,
#  'NETI[],': False,
#  'THNENAGRRQ': False,
#  'NAFV': False,
#  'CBFFVOYR.)': False,
#  '*/': False,
#  'ZNVA(I,P)PUNE**P;{SBE(I[P++]="URYYB,': False,
#  'JBEYQ!\\A)";': False,
#  '(!!P)[*P]&&(I--||--P&&RKRPYC(*P,*P,P[!!P]+!!P,!P));': False,
#  '**P=!P)JEVGR(!!*P,*P,!!**P);}': False,
#  "URER'F": False,
#  'NABGURE': False,
#  'BAR:': False,
#  'PBZCHGR': False,
#  'NCCEBKVZNGVBA': False,
#  'CV': False,
#  'OEVNA': False,
#  'JRFGYRL,': False,
#  '1988': False,
#  '(ERDHVERF': False,
#  'CPP': False,
#  'ZNPEB': False,
#  'PBAPNGRANGVBA;': False,
#  'GEL': False,
#  'TPP': False,
#  '-GENQVGVBANY-PCC)': False,
#  '#QRSVAR': False,
#  '_': False,
#  '-S<00||--S-BB--;': False,
#  'VAG': False,
#  'S=00,BB=00;': False,
#  'ZNVA(){S_BB();CEVAGS("%1.3S\\A",4.*-S/BB/BB);}S_BB()': False,
#  '{': False,
#  '_-_-_-_': False,
#  '_-_-_-_-_-_-_-_-_': False,
#  '_-_-_-_-_-_-_-_-_-_-_-_': False,
#  '_-_-_-_-_-_-_-_-_-_-_-_-_-_': False,
#  '_-_-_-_-_-_-_-_-_-_-_-_-_-_-_': False,
#  '_-_-_-_-_-_-_-_-_-_-_-_-_-_-_-_': False,
#  '_-_-_-_-_-_-_-_': False,
#  '}': False,
#  'ABGR': False,
#  'PBZCHGVAT': False,
#  ...}

# %%
list_of_values = []
for key, value in frequency_dictionary_new.items():
    list_of_values.append(value)

# %%
list_of_values
# Out:
# [3.4,
#  6.59,
#  5.5,
#  7.08,
#  5.68,
#  3.05,
#  2.58,
#  3.33,
#  15.26,
#  10.13,
#  7.0,
#  2.8,
#  1.71,
#  0.67,
#  6.14,
#  5.64,
#  1.45,
#  2.42,
#  0.41,
#  0.9,
#  1.04,
#  3.28,
#  0.46,
#  1.45,
#  0.12,
#  1.74,
#  0.09,
#  0.09,
#  0.0]

# %%
len(list_of_values)
# Out:
# 29

# %%
sorted_list = sorted(list_of_values)

# %%
print(sorted_list)
# Out:
# [0.0, 0.09, 0.09, 0.12, 0.41, 0.46, 0.67, 0.9, 1.04, 1.45, 1.45, 1.71, 1.74, 2.42, 2.58, 2.8, 3.05, 3.28, 3.33, 3.4, 5.5, 5.64, 5.68, 6.14, 6.59, 7.0, 7.08, 10.13, 15.26]

# %%
sorted_list = sorted_list[::-1]

# %%
sorted_list
# Out:
# [15.26,
#  10.13,
#  7.08,
#  7.0,
#  6.59,
#  6.14,
#  5.68,
#  5.64,
#  5.5,
#  3.4,
#  3.33,
#  3.28,
#  3.05,
#  2.8,
#  2.58,
#  2.42,
#  1.74,
#  1.71,
#  1.45,
#  1.45,
#  1.04,
#  0.9,
#  0.67,
#  0.46,
#  0.41,
#  0.12,
#  0.09,
#  0.09,
#  0.0]
